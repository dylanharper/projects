# %%
# !pip install beautifulsoup4
# Out:
# ...
#      |████████████████████████████████| 102kB 90kB/s ta 0:00:011
# ...

# %%
from google.cloud import storage
import json
from dateutil.parser import parse
from bs4 import BeautifulSoup

# %%
storage_client = storage.Client()
bucket = storage_client.bucket('dotufp-raw')
blob_name = 'web_scrape/politicalwire/2019-11-27T06:00:03Z.raw'
collected_timestamp = '2019-11-27T06:00:03Z'
blob = bucket.blob(blob_name)
raw_str = blob.download_as_string()

raw_str[:1000]
# Out:
# /home/dylan/anaconda3/lib/python3.7/site-packages/google/auth/_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ...

# %%
soup = BeautifulSoup(raw_str)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# website: http://ogp.me/ns/website#">
#  <head itemscope="" itemtype="https://schema.org/WebSite">
#   <meta charset="utf-8"/>
#   <meta content="All the political news in one place" name="description"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script data-cfasync="false" id="ao_optimized_gfonts_config" type="text/javascript">
#    WebFontConfig={google:{families:["Roboto:300,400","Roboto Slab:300,400"] },classes:false, events:false, timeout:1500};
#   </script>
#   <link href="https://1lme911nv0cg3ned26127983-wpengine.netdna-ssl.com/wp-content/cache/autoptimize/css/autoptimize_16e361a0a88ecd67b8576b37758a3db6.css" media="all" rel="stylesheet" type="text/css"/>
#   <title>
#    Political Wire
#   </title>
#   <link href="//s0.wp.com" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://fonts.gstatic.com" rel="preconnect"/>
# ...

# %%
soup.find(text="Trump Moves to Shore Up Florida")
# Out:
# 'Trump Moves to Shore Up Florida'

# %%
soup.find_all("a", "entry-title-link")
# Out:
# [<a class="entry-title-link" href="https://politicalwire.com/2019/11/26/trump-supporters-chant-bullshit-at-rally/" rel="bookmark">Trump Supporters Chant ‘Bullshit’ at Rally</a>,
#  <a class="entry-title-link" href="https://politicalwire.com/2019/11/26/buttigieg-surges-in-new-hampshire/" rel="bookmark">Buttigieg Surges In New Hampshire</a>,
#  <a class="entry-title-link" href="https://politicalwire.com/2019/11/26/anonymous-will-reveal-their-identity/" rel="bookmark">Anonymous Will Reveal Their Identity</a>,
#  <a class="entry-title-link" href="https://politicalwire.com/2019/11/26/trump-knew-of-complaint-when-he-released-aid/" rel="bookmark">Trump Knew of Complaint When He Released Aid</a>,
#  <a class="entry-title-link" href="https://politicalwire.com/2019/11/26/trump-denies-sending-giuliani-to-ukraine-for-biden-probe/" rel="bookmark">Trump Denies Sending Giuliani to Ukraine for Biden</a>,
# ...
